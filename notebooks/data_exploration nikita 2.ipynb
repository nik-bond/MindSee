# %%
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt
import pickle
import pandas as pd

# %%
pwd
# Out:
# '/home/nik/code/nik-bond/MindSee/notebooks'

# %%
# Read H5 file
images_file = h5.File("../data/nsd_stimuli.hdf5", "r")
images = images_file['imgBrick']

# %%
plt.imshow(images[46002])
plt.show()

# %%
# with open('../data/nsd_stim_info_merged.pkl', 'rb') as file:
#     data = pickle.load(file,encoding="latin1")

# %%
# data.columns

# %%
# data[['nsdId','cocoId','subject1', 'cocoSplit', ]].head(50)

# %%
plt.imshow(images[61882])
plt.show()

# %%
X_test=np.load('../data/nsd_test_fmriavg_nsdgeneral_sub1.npy')

# %%
X_test.shape
# Out:
# (982, 15724)

# %%
X_train=np.load('../data/nsd_train_fmriavg_nsdgeneral_sub1.npy')

# %%
X_train[0]
# Out:
# array([-208.66667175,   10.33333302,  222.        , ...,  508.        ,
#        1158.        ,  771.66668701])

# %%
test_caps=np.load('../data/nsd_test_cap_sub1.npy')

# %%
train_caps=np.load('../data/nsd_train_cap_sub1.npy')

# %%
train_caps[7]
# Out:
# array(['The parking meters are posted beside a cement wall. ',
#        'A row of parking meters sitting along a cement fence.',
#        'A bunch of parking tolls near a concrete wall with numbers',
#        'Parking meters in pavement with corresponding numbered poles.',
#        ''], dtype='<U250')

# %%
X_train.shape
# Out:
# (8859, 15724)

# %%
stim_list_train=np.load('../data/subj01_nsd_train_stim_list1.npy')

# %% [markdown]
# Index for first image

# %%
stim_list_train[0]
# Out:
# 61882

# %% [markdown]
# Image retrieved using index

# %%
plt.imshow(images[61882])
plt.show()

# %% [markdown]
# Train caption

# %%
train_caps[10]
# Out:
# array(['', '', 'A cat hiding behind a laptop and box', '', ''],
#       dtype='<U250')

# %%
stim_list_test=np.load('../data/nsd_test_stim_list1.npy')

# %%
stim_list_test[0]
# Out:
# 46002

# %%
test_caps[0]
# Out:
# array(['White cows eating grass under trees and the sky', '', '', '', ''],
#       dtype='<U250')

# %% [markdown]
# Comparing to subj indeces from COCO

# %%
# coco_idc = h5.File('COCO_73k_subj_indices.hdf5','r+')

# %%
# coco_annots=np.load('COCO_73k_annots.npy')

# %%
# coco_annots[61882]

# %%
# coco_annots.shape

# %%
# coco_annots_curated=np.load('COCO_73k_annots_curated.npy')

# %%
# coco_annots_curated[61882]

# %%
# subj01_annot=np.load('subj01_annot.npy',allow_pickle=True)

# %%
# subj01_annot[0:6]

# %%
train_caps[0:5]
# Out:
# array([['', 'A man standing on the beach beside surf boards', '',
#         'a man is flying a kite over a beach', ''],
#        ['A man on a surfboard, who is riding a wave.',
#         'A man riding a wave on top of a surfboard in the ocean.', '',
#         'A guy in a wet suite riding a surfboard on a wave.', ''],
#        ['', '', '', '',
#         'A group of people are sitting on the beach shore.'],
#        ['A shower and a white toilet in a small bathroom.', '',
#         'a bathroom with a toilet and a sink and a shower',
#         'a bathroom with a glass shower and white toilet',
#         'A bathroom with a toilet, shower stall, sink and a mirror.'],
#        ['', '', '', 'two grown zebra inside some kind of enclosure', '']],
#       dtype='<U250')

# %%
stim_list_train[10]
# Out:
# 18039

# %% [markdown]
# ### See image from caption index

# %%
X_train=np.load('../data/nsd_train_fmriavg_nsdgeneral_sub1.npy')
train_caps=np.load('../data/nsd_train_cap_sub1.npy')
stim_list_train=np.load('../data/subj01_nsd_train_stim_list1.npy')
images_file = h5.File("../data/nsd_stimuli.hdf5", "r")
images = images_file['imgBrick']

stim_list_test=np.load('../data/nsd_test_stim_list1.npy')
test_caps=np.load('../data/nsd_test_cap_sub1.npy')
X_test=np.load('../data/nsd_test_fmriavg_nsdgeneral_sub1.npy')

# %%
index_caption = 0
index2 =stim_list_train[index_caption]
plt.imshow(images[index2])
plt.show()

print('Original captions', train_caps[index_caption])
print('fMRI array', X_train[index_caption])
# Out:
# Original captions ['' 'A man standing on the beach beside surf boards' ''
#  'a man is flying a kite over a beach' '']
# fMRI array [-208.66667175   10.33333302  222.         ...  508.         1158.
#   771.66668701]

# %% [markdown]
# ## Create train and test dataframes

# %%
stim_list_test=np.load('../data/nsd_test_stim_list1.npy')

# %%
train_caps_processed = pd.read_csv('../data/X_train_captions.csv')

# %%
print(train_caps_processed.shape)
print(stim_list_train.shape)
print(X_train.shape)
# Out:
# (8859, 3)
# (8859,)
# (8859, 15724)

# %%
X_train
# Out:
# array([[-2.08666672e+02,  1.03333330e+01,  2.22000000e+02, ...,
#          5.08000000e+02,  1.15800000e+03,  7.71666687e+02],
#        [ 6.25333313e+02,  1.05000000e+02,  2.61000000e+02, ...,
#          4.95000000e+02,  7.87333313e+02,  5.37666687e+02],
#        [ 7.84000000e+02, -9.30000000e+01, -3.46666679e+01, ...,
#          3.33333343e-01,  2.02666672e+02,  2.63000000e+02],
#        ...,
#        [ 7.36000000e+02, -4.62000000e+02,  3.00000000e+02, ...,
#          1.97000000e+02,  7.04000000e+02, -1.45000000e+02],
#        [ 1.10250000e+03, -1.47000000e+02,  2.94000000e+02, ...,
#          2.70500000e+02,  7.33000000e+02,  2.32000000e+02],
#        [ 2.00000000e+02, -4.57000000e+02,  1.54000000e+02, ...,
#          3.20000000e+01,  4.87000000e+02,  1.94000000e+02]])

# %%
train_caps_processed['captions'].shape
# Out:
# (8859,)

# %%
df_train = pd.DataFrame({'Image_index': stim_list_train, 'train_caps_processed': train_caps_processed['captions']})

# %%
df_train
# Out:
#       Image_index                      train_caps_processed
# 0           61882         ['man', 'stand', 'beach', 'surf']
# 1             828         ['surfboard', 'wave', 'man', ' ']
# 2           67573       ['beach', 'people', 'group', 'sit']
# 3           16020  ['toilet', 'shower', 'sink', 'bathroom']
# 4           40422       ['enclosure', 'grow', 'zebra', ' ']
# ...           ...                                       ...
# 8854        50154      ['person', 'walk', 'bridge', 'kite']
# 8855        48882       ['cat', 'couple', 'black', 'couch']
# 8856        32084        ['ocean', 'person', 'rid', 'wave']
# 8857        30415         ['fly', 'people', 'kit', 'large']
# 8858        26742   ['sky', 'colorful', 'kit', 'different']
#
# [8859 rows x 2 columns]

# %%
df_train['fMRI']=list(X_train)

# %%
df_train
# Out:
#       Image_index                      train_caps_processed  \
# 0           61882         ['man', 'stand', 'beach', 'surf']
# 1             828         ['surfboard', 'wave', 'man', ' ']
# 2           67573       ['beach', 'people', 'group', 'sit']
# 3           16020  ['toilet', 'shower', 'sink', 'bathroom']
# 4           40422       ['enclosure', 'grow', 'zebra', ' ']
# ...           ...                                       ...
# 8854        50154      ['person', 'walk', 'bridge', 'kite']
# 8855        48882       ['cat', 'couple', 'black', 'couch']
# 8856        32084        ['ocean', 'person', 'rid', 'wave']
# 8857        30415         ['fly', 'people', 'kit', 'large']
# 8858        26742   ['sky', 'colorful', 'kit', 'different']
#
#                                                    fMRI
# 0     [-208.6666717529297, 10.333333015441895, 222.0...
# 1     [625.3333129882812, 105.0, 261.0, 486.66665649...
# 2     [784.0, -93.0, -34.66666793823242, 356.0, 769....
# 3     [76.66666412353516, -458.6666564941406, -69.66...
# 4     [-202.0, 86.0, -133.5, 392.5, 518.5, 388.5, -1...
# ...                                                 ...
# 8854  [1259.0, -440.0, 336.0, 604.0, 939.0, 737.0, -...
# 8855  [607.0, -71.0, -186.0, 351.0, 992.0, 343.0, 89...
# 8856  [736.0, -462.0, 300.0, 439.0, -37.0, -65.0, -1...
# 8857  [1102.5, -147.0, 294.0, 792.0, 1031.0, 606.0, ...
# 8858  [200.0, -457.0, 154.0, 348.0, 230.0, -158.0, -...
#
# [8859 rows x 3 columns]

# %%
len(df_train['fMRI'][0])
# Out:
# 15724

# %%
test_caps_processed = pd.read_csv('../data/X_test_captions.csv')

# %%
test_caps_processed
# Out:
#      Unnamed: 0  indices                                captions
# 0             0        0        ['cow', 'white', 'grass', 'eat']
# 1             1        1  ['airplane', 'port', 'cloud', 'plane']
# 2             2        2  ['airplane', 'sky', 'build', 'sunset']
# 3             3        3    ['kitchen', 'view', 'middle', 'day']
# 4             4        4     ['clock', 'center', 'tile', 'star']
# ..          ...      ...                                     ...
# 977         977      977     ['snowy', 'slope', 'ski', 'people']
# 978         978      978      ['giraffe', 'small', 'green', ' ']
# 979         979      979      ['dog', 'lie', 'inside', 'purple']
# 980         980      980        ['ski', 'snowboard', 'man', ' ']
# 981         981      981         ['man', 'tie', 'glass', 'look']
#
# [982 rows x 3 columns]

# %%
print(test_caps_processed.shape)
print(stim_list_test.shape)
print(X_test.shape)
# Out:
# (982, 3)
# (982,)
# (982, 15724)

# %%
df_test = pd.DataFrame({'Image_index': stim_list_test, 'test_caps_processed': test_caps_processed['captions'], 'fMRI' : list(X_test)})

# %%
df_test
# Out:
#      Image_index                     test_caps_processed  \
# 0          46002        ['cow', 'white', 'grass', 'eat']
# 1          48617  ['airplane', 'port', 'cloud', 'plane']
# 2          44980  ['airplane', 'sky', 'build', 'sunset']
# 3          32625    ['kitchen', 'view', 'middle', 'day']
# 4          53052     ['clock', 'center', 'tile', 'star']
# ..           ...                                     ...
# 977        19672     ['snowy', 'slope', 'ski', 'people']
# 978        18535      ['giraffe', 'small', 'green', ' ']
# 979        21318      ['dog', 'lie', 'inside', 'purple']
# 980        32857        ['ski', 'snowboard', 'man', ' ']
# 981        30935         ['man', 'tie', 'glass', 'look']
#
#                                                   fMRI
# 0    [-339.6666564941406, -236.6666717529297, 13.66...
# 1    [277.5, -418.0, 14.5, 329.0, 509.0, 170.0, -33...
# 2    [69.0, 177.0, -49.66666793823242, 554.33331298...
# 3    [366.6666564941406, -412.0, 42.33333206176758,...
# 4    [-49.33333206176758, -321.6666564941406, 31.33...
# ..                                                 ...
# 977  [878.6666870117188, 259.6666564941406, 51.0, 6...
# 978  [531.0, 104.0, -336.5, 262.5, 7.5, 199.5, 1066...
# 979  [255.6666717529297, -48.66666793823242, -91.66...
# 980  [1133.0, 331.0, 385.0, 932.0, 1364.0, 969.0, 1...
# 981  [-439.0, -320.0, 38.0, 385.0, -41.0, 391.0, -1...
#
# [982 rows x 3 columns]

# %%
df_train
# Out:
#       Image_index                      train_caps_processed  \
# 0           61882         ['man', 'stand', 'beach', 'surf']
# 1             828         ['surfboard', 'wave', 'man', ' ']
# 2           67573       ['beach', 'people', 'group', 'sit']
# 3           16020  ['toilet', 'shower', 'sink', 'bathroom']
# 4           40422       ['enclosure', 'grow', 'zebra', ' ']
# ...           ...                                       ...
# 8854        50154      ['person', 'walk', 'bridge', 'kite']
# 8855        48882       ['cat', 'couple', 'black', 'couch']
# 8856        32084        ['ocean', 'person', 'rid', 'wave']
# 8857        30415         ['fly', 'people', 'kit', 'large']
# 8858        26742   ['sky', 'colorful', 'kit', 'different']
#
#                                                    fMRI
# 0     [-208.6666717529297, 10.333333015441895, 222.0...
# 1     [625.3333129882812, 105.0, 261.0, 486.66665649...
# 2     [784.0, -93.0, -34.66666793823242, 356.0, 769....
# 3     [76.66666412353516, -458.6666564941406, -69.66...
# 4     [-202.0, 86.0, -133.5, 392.5, 518.5, 388.5, -1...
# ...                                                 ...
# 8854  [1259.0, -440.0, 336.0, 604.0, 939.0, 737.0, -...
# 8855  [607.0, -71.0, -186.0, 351.0, 992.0, 343.0, 89...
# 8856  [736.0, -462.0, 300.0, 439.0, -37.0, -65.0, -1...
# 8857  [1102.5, -147.0, 294.0, 792.0, 1031.0, 606.0, ...
# 8858  [200.0, -457.0, 154.0, 348.0, 230.0, -158.0, -...
#
# [8859 rows x 3 columns]

# %%
pwd
# Out:
# '/home/nik/code/nik-bond/MindSee/notebooks'

# %%
# df_train.to_csv('../data/df_train.csv', index=False)
# df_test.to_csv('../data/df_test.csv', index=False)

# %%
img_idx=3164
plt.imshow(images[img_idx])
plt.show()

# print('Original captions', test_caps[img_idx])
# print('fMRI array', X_test[img_idx])

# %%
index_caption = 1
index2 =stim_list_test[index_caption]
plt.imshow(images[index2])
plt.show()

print('Original captions', test_caps[index_caption])
print('fMRI array', X_test[index_caption])
# Out:
# Original captions ['' '' 'There is a plane pulled into a port under the clouds.' ''
#  'An airplane sits at the airport waiting to be loaded.']
# fMRI array [ 277.5 -418.    14.5 ...  122.   436.5  461. ]

# %%
index_caption = 8854
index2 =stim_list_train[index_caption]
plt.imshow(images[index2])
plt.show()

print('Original captions', train_caps[index_caption])
print('fMRI array', X_train[index_caption])
# Out:
# Original captions ['A person walks on a bridge with a kite.' '' '' '' '']
# fMRI array [1259. -440.  336. ...  288. 1410.  720.]
